# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("germination.csv")
data
# Out:
#      Unnamed: 0  temp species  start  end  germinated
# 0             1    10   wheat      0    1           0
# 1             2    10   wheat      1    2           0
# 2             3    10   wheat      2    3           0
# 3             4    10   wheat      3    4           0
# 4             5    10   wheat      4    5           0
# ..          ...   ...     ...    ...  ...         ...
# 187         188    40    rice     13   14           0
# 188         189    40    rice     14   16           0
# 189         190    40    rice     16   17           0
# 190         191    40    rice     17   18           0
# 191         192    40    rice     18   20          12
#
# [192 rows x 6 columns]

# %%
data = data.groupby(["species","temp","end"], sort=False)["germinated"].max()

# %%
data.unstack().T.plot(kind="bar", subplots=False, layout=(2,2),figsize=(20,10), width=1)
# Out:
# <AxesSubplot:xlabel='end'>
